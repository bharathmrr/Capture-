# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathmrr/Capture-/blob/main/Untitled48.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
x=data['total_bedrooms']
y=data.iloc[:,-1]

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# Reshape x_train to a 2D array before fitting the model
x_train = x_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1,1) #Reshape x_test to a 2D array as well.

# Now you can fit the model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_test
# Out:
# 1291     92300.0
# 595      65500.0
# 236     309100.0
# 2824     69500.0
# 1290    234300.0
#           ...
# 2236     47500.0
# 1448    114800.0
# 1189    243800.0
# 8       194400.0
# 310     155500.0
# Name: median_house_value, Length: 600, dtype: float64

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,color='red')

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.004701887721776377
